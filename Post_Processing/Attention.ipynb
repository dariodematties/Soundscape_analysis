# %% [markdown]
# # Generate attentional maps and masks from image

# %%
from collections import namedtuple

import visualize_attention

# %% [markdown]
# Compose the arguments

# %%
Arguments = namedtuple('Arguments', ['arch',
                                     'patch_size',
                                     'pretrained_weights',
                                     'checkpoint_key',
                                     'image_path',
                                     'image_size',
                                     'output_dir',
                                     'threshold'
                                    ])

args = Arguments(arch = 'vit_small',
                 patch_size = 16,
                 #pretrained_weights = '/grand/projects/BirdAudio/Soundscapes/Models/SecondModel/checkpoint0045.pth',
                 pretrained_weights = '/grand/projects/BirdAudio/Soundscapes/Models/checkpoint0200.pth',
                 checkpoint_key = "teacher",
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Mel_Spectrograms/set2/00004862/20210714_STUDY/20210714T170000-0500_Rec_66.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Filtered_Spectrograms/set2/00004862/20210714_STUDY/20210714T170000-0500_Rec_687.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Mel_Spectrograms/set1/00023734/20210628_STUDY/20210628T170000-0500_Rec_1504.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Spectrograms/set2/00004862/20210714_STUDY/20210714T170000-0500_Rec_188.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Spectrograms/set1/00023734/20210628_STUDY/20210628T170000-0500_Rec_234.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Spectrograms/set1/00023734/20210630_STUDY/20210630T030854-0500_Rec_1056.png',
                 #image_path = '/media/dario/T7_Touch/Temp_folder/Spectrograms/set1/00023734/20210701_STUDY/20210701T030854-0500_Rec_1160.png',
                 #image_path = '/media/dario/T7_Touch/Temp_folder/Spectrograms/set1/00023734/20210628_STUDY/20210628T170000-0500_Rec_1000.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Second_Filtered_Spectrograms/set1/00023764/20210524_STUDY/20210524T230000+0000_REC_387.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Second_Filtered_Spectrograms/set1/00023764/20210526_STUDY/20210526T140000+0000_REC_64.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Second_Filtered_Spectrograms/set1/00023764/20210524_STUDY/20210524T230000+0000_REC_355.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Second_Filtered_Spectrograms/set1/00023764/20210526_STUDY/20210526T000000+0000_REC_388.png',
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Second_Filtered_Spectrograms/set2/00023764/20210722_STUDY/20210722T063138+0000_REC_2185.png',
                 image_path = '/grand/projects/BirdAudio/Soundscapes/NIPS4Bplus/Spectrograms/train/nips4b_birds_trainfile291_3.png',
                 #
                 #image_path = '/grand/projects/BirdAudio/Soundscapes/Second_Filtered_Spectrograms/set1/00023764/20210524_STUDY/20210524T230000+0000_REC_18.png',
                 #image_size = (1024, 1024),
                 #image_size = (3*349, 3*475),
                 image_size = (5*442, 5*85),
                 #image_size = (2*442, 2*774),
                 #image_size = (3*128, 3*517),
                 output_dir = '/grand/projects/BirdAudio/Soundscapes/NIPS4Bplus/Single_Image_Attentional_Maps',
                 #output_dir = '/grand/projects/BirdAudio/Soundscapes/Single_Image_Attentional_Maps',
                 #output_dir = '/media/dario/T7_Touch/Temp_folder/Single_Image_Attentional_Maps',
                 threshold = 0.2
                )

# %% [markdown]
# Generate attentional maps and masks from image

# %%
visualize_attention.main(args)
# Out:
# Take key teacher in provided checkpoint dict
# Pretrained weights found at /grand/projects/BirdAudio/Soundscapes/Models/checkpoint0200.pth and loaded with msg: _IncompatibleKeys(missing_keys=[], unexpected_keys=['head.mlp.0.weight', 'head.mlp.0.bias', 'head.mlp.2.weight', 'head.mlp.2.bias', 'head.mlp.4.weight', 'head.mlp.4.bias', 'head.last_layer.weight_g', 'head.last_layer.weight_v'])
# /grand/projects/BirdAudio/Soundscapes/NIPS4Bplus/Single_Image_Attentional_Maps/attn-head0.png saved.
# /grand/projects/BirdAudio/Soundscapes/NIPS4Bplus/Single_Image_Attentional_Maps/attn-head1.png saved.
# /grand/projects/BirdAudio/Soundscapes/NIPS4Bplus/Single_Image_Attentional_Maps/attn-head2.png saved.
# /grand/projects/BirdAudio/Soundscapes/NIPS4Bplus/Single_Image_Attentional_Maps/attn-head3.png saved.
# /grand/projects/BirdAudio/Soundscapes/NIPS4Bplus/Single_Image_Attentional_Maps/attn-head4.png saved.
# ...

# %% [markdown]
# # Get features from individual image

# %%
import get_feat_from_image

# %%
get_feat_from_image.main(args)
# Out:
# Take key teacher in provided checkpoint dict
# Pretrained weights found at /grand/projects/BirdAudio/Soundscapes/Models/checkpoint0200.pth and loaded with msg: _IncompatibleKeys(missing_keys=[], unexpected_keys=['head.mlp.0.weight', 'head.mlp.0.bias', 'head.mlp.2.weight', 'head.mlp.2.bias', 'head.mlp.4.weight', 'head.mlp.4.bias', 'head.last_layer.weight_g', 'head.last_layer.weight_v'])
# Image and its features saved.
